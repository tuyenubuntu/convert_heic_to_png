# %%
import os
from os import path
import glob
import shutil
from PIL import Image
from heic2png import HEIC2PNG
path =''
#os.listdir(os.path.expanduser('*.heic'))
lst = glob.glob(os.path.join(path,'*heic'))
print (type(lst))
for i in lst:
    if os.path.exists('Convert') == False:
        name_folder = 'Convert'
        os.mkdir(name_folder)
    else:
        pass
    try:
        shutil.copy(os.path.join(path,i),os.path.join(path,f'{name_folder}/{i}'))
        #print("File copied successfully.")
        img = HEIC2PNG(os.path.join(path,f'{name_folder}/{i}'), quality = 90)
        img.save()
        os.remove(os.path.join(path,f'{name_folder}/{i}'))
        print(f"File {i} converted successfully to *.png.") 
    # If source and destination are same
    except shutil.SameFileError:
        print("Source and destination represents the same file.")
    # If there is any permission issue
    except PermissionError:
        print("Permission denied.")
    # For other errors
    except:
        print("Error occurred while copying file.")

print ('Finish ALL!')


lst2 = glob.glob(os.path.join(path,'*jpg'))
for i in lst2:
    shutil.copy(os.path.join(path,i),os.path.join(path,f'{name_folder}/{i}'))
len(lst2 + lst)
print ('Done')
# Out:
# <class 'list'>
# File 20240620_030151534_iOS.heic converted successfully to *.png.
# File 20240620_030153489_iOS.heic converted successfully to *.png.
# File 20240620_030427507_iOS.heic converted successfully to *.png.
# File 20240620_030431416_iOS.heic converted successfully to *.png.
# File 20240620_030436192_iOS.heic converted successfully to *.png.
# File 20240620_030523783_iOS.heic converted successfully to *.png.
# File 20240620_030531998_iOS.heic converted successfully to *.png.
# File 20240620_030737438_iOS.heic converted successfully to *.png.
# File 20240620_030738465_iOS.heic converted successfully to *.png.
# File 20240620_030934160_iOS.heic converted successfully to *.png.
# File 20240620_031009928_iOS.heic converted successfully to *.png.
# File 20240620_031011418_iOS.heic converted successfully to *.png.
# File 20240620_031017555_iOS.heic converted successfully to *.png.
# File 20240620_031212436_iOS.heic converted successfully to *.png.
# File 20240620_031357969_iOS.heic converted successfully to *.png.
# File 20240620_031403418_iOS.heic converted successfully to *.png.
# File 20240620_031454586_iOS.heic converted successfully to *.png.
# File 20240620_031505777_iOS.heic converted successfully to *.png.
# File 20240620_031900167_iOS.heic converted successfully to *.png.
# File 20240620_031908924_iOS.heic converted successfully to *.png.
# File 20240620_032229234_iOS.heic converted successfully to *.png.
# File 20240620_032233219_iOS.heic converted successfully to *.png.
# File 20240620_032246995_iOS.heic converted successfully to *.png.
# File 20240620_032409223_iOS.heic converted successfully to *.png.
# File 20240620_032413103_iOS.heic converted successfully to *.png.
# File 20240620_032442864_iOS.heic converted successfully to *.png.
# File 20240620_032624025_iOS.heic converted successfully to *.png.
# File 20240620_033704578_iOS.heic converted successfully to *.png.
# File 20240620_033719999_iOS.heic converted successfully to *.png.
# File 20240620_033723341_iOS.heic converted successfully to *.png.
# File 20240620_033829833_iOS.heic converted successfully to *.png.
# File 20240620_033846983_iOS.heic converted successfully to *.png.
# File 20240620_033851083_iOS.heic converted successfully to *.png.
# File 20240620_034043735_iOS.heic converted successfully to *.png.
# File 20240620_034047534_iOS.heic converted successfully to *.png.
# File 20240620_034256362_iOS.heic converted successfully to *.png.
# File 20240620_034300774_iOS.heic converted successfully to *.png.
# File 20240620_034641097_iOS.heic converted successfully to *.png.
# File 20240620_034643879_iOS.heic converted successfully to *.png.
# File 20240620_035053152_iOS.heic converted successfully to *.png.
# File 20240620_035058468_iOS.heic converted successfully to *.png.
# File 20240620_035101834_iOS.heic converted successfully to *.png.
# File 20240620_035608913_iOS.heic converted successfully to *.png.
# File 20240620_035809989_iOS.heic converted successfully to *.png.
# File 20240620_040219987_iOS.heic converted successfully to *.png.
# File 20240620_040332464_iOS.heic converted successfully to *.png.
# File 20240620_040415282_iOS.heic converted successfully to *.png.
# File 20240620_040424840_iOS.heic converted successfully to *.png.
# File 20240620_040427402_iOS.heic converted successfully to *.png.
# File 20240620_040508341_iOS.heic converted successfully to *.png.
# File 20240620_040512142_iOS.heic converted successfully to *.png.
# File 20240620_040518020_iOS.heic converted successfully to *.png.
# File 20240620_040652546_iOS.heic converted successfully to *.png.
# File 20240620_040655808_iOS.heic converted successfully to *.png.
# File 20240620_040833901_iOS.heic converted successfully to *.png.
# File 20240620_041034283_iOS.heic converted successfully to *.png.
# File 20240620_041037130_iOS.heic converted successfully to *.png.
# File 20240620_041506994_iOS.heic converted successfully to *.png.
# File 20240620_041510956_iOS.heic converted successfully to *.png.
# File 20240620_042120680_iOS.heic converted successfully to *.png.
# File 20240620_042225757_iOS.heic converted successfully to *.png.

# %%
len(lst2 + lst)
